# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ax_x = [0., 1.01, 2., 3., 4., 5., 6., 7.1, 8., 9., 10.1, 11.1, 1.25, 1.5, 1.75, 2.25, 2.5, 2.76, 6.4, 6.82, 7.2, 7.63, 5.5]
ax_y = [0.08, 19.7, 154.3, 74.4, 46.7, 35.4, 30.8, 34., 35.1, 35.3, 50., 58.9, 63., 120.7, 156., 137.2, 115.8, 97., 33.3, 33., 33.8, 34.6, 37.1]
plt.figure(figsize=(12, 9))
plt.plot(ax_x, ax_y, 'bo')
ax_x = [0., 1., 2., 3., 4., 5., 6.1, 7.1, 8., 9., 10.1, 11.1, 1.27, 1.51, 1.75, 2.25, 2.51, 2.75, 5.5, 6.5, 7.54]
ax_y = [0., 29.2, 163.8, 111.7, 85.4, 72.4, 66.7, 67.6, 73., 84.7, 115., 135., 89., 142., 171., 152.5, 137., 124.7, 73., 67.1, 73.]
plt.plot(ax_x, ax_y, 'ro')
plt.xlabel('Vк-с, В')
plt.ylabel('Va, мВ')
plt.title('V накала = 2,61В')
plt.grid()
plt.show()

# %%
ax_x = [0., 1., 2., 3., 4., 5., 6.1, 7.1, 8., 9., 10.1, 11.1, 1.27, 1.51, 1.75, 2.25, 2.51, 2.75, 5.5, 6.5, 7.54]
ax_y = [0., 29.2, 163.8, 111.7, 85.4, 72.4, 66.7, 67.6, 73., 84.7, 115., 135., 89., 142., 171., 152.5, 137., 124.7, 73., 67.1, 73.]
plt.figure(figsize=(12, 9))
plt.plot(ax_x, ax_y, 'bo')
plt.xlabel('Vк-с, В')
plt.ylabel('Va, мВ')
plt.title('V накала = 2,82В')
plt.grid()
plt.show()
