# %% [markdown]
# #Нелинейные задачи. Теория.

# %% [markdown]
# ##Переопределенные задачи, линейный случай.

# %% [markdown]
# При рассмотрении систем уравнений не всегда совпадает число уравнений и неизвестных. Рассмотрим систему с $m$ неизвестными и $n$ уравнениями, где $n>>m$.
#
# У данной системы почти наверняка нет точного решения. Некоторые (зачастую все) коэффициенты данной системы посчитаны с некоторой погрешностью, из-за чего и невозможно найти точное решение. В данном случае можно найти обощенное решение данной системы. Для этого будем минимизировать некоторый функционал.
#
# Рассмотрим невязку $i$ уравнения :
#
# $r_i = \sum\limits_{k = 1}^{m}a_{ik}x_k - f_k$
#
# Будем минимизировать функционал основанный на невязке, например :
#
# $\Phi(x) = \sum\limits_{i = 1}^{n}r_i^2 \rightarrow min$
#
# Сделать это можно различными способами.
# Напомним, что было и явное решение.
#
# По методу наименьших квадратов для решения несовместной СЛАУ $A x=b$, состоящей из $\mathbb{M}$ уравнений с $N$ неизвестными, необходимо решить уравнение
# $$
# A^T A x=A^T b,
# $$
# называемое нормальным уравнением. Пусть столбцы матрицы $A$ линейно независимы, тогда она обратима и система имеет единственное решение
# $$
# x=\left(A^T A\right)^{-1} A^T b .
# $$
# Таким образом мы приходим к понятию псевдообращения действительных матриц:
# $$
# A^{+}=\left(A^T A\right)^{-1} A^T .
# $$
#
# Этот метод и нормальное уравнение можно обобщить на случай нелинейной регрессионной модели.

# %% [markdown]
# ## Регрессионная модель в нелинейном случае (метод Гаусса-Ньютона).

# %% [markdown]
# Рассмотрим еще более общий случай.
# Пусть задана выборка из n пар $(x_i, y_i)$ . Задана регрессионная модель $f(w,x)$ , которая зависит от параметров $w = (w_1, w_2, ... , w_W)$ и свободной переменной х. Требуется найти такие значения параметров, которые доставляли бы минимум сумме квадратов регрессионных остатков:
#
# $S = \sum\limits_{i = 1}^{n}r_i^2 \rightarrow min$
#
# Так как функция $S$ в общем случае не имеет единственного минимума, то предлагается назначить начальное значение вектора параметров $w_0$ и приближаться к оптимальному вектору по шагам:
#
# $w_j \approx w^{k+1}_j = w^{k}_j + Δw^k_j$
#
# На каждом шаге итерации линеаризуем модель с помощью приближения рядом Тейлора относительно параметров:
#
# $f(w,x_i) \approx f(w^k,x_i)  +  \sum\limits_{j = 1}^{n}J_{ij}Δw^k_j $
#
# $$
# J_{ij} =-\frac{∂r_i}{∂w_j}  \approx \frac{∂f(w^k,x_i)}{∂w_j}
# $$
#
# Тогда регрессионные остатки можно записать в виде:
#
# $$
# r_{j} = Δy^k_j  - \sum\limits_{j = 1}^{n}J_{ij}Δw^k_j; Δy^k_j = y_j - f(w^k,x_i)
# $$
#
# Приравняем к нулю первые частные производные S по параметрам. Подставим туда новую формулу для регрессионных остатков:
#
# $$
# -2\sum\limits_{j = 1}^{n}J_{ij}(Δy^k_j - \sum\limits_{s = 1}^{n}J_{is}Δw^k_s ) = 0
# $$
#
# Преобразуя, получаем систему из n линейных уравнений, которые называются нормальным уравнением
#
# $$
# \sum\limits_{j = 1}^{n}\sum\limits_{s = 1}^{n}J_{ij}J_{is}Δw^k_s  = \sum\limits_{j = 1}^{n}J_{ij}Δy^k_j
# $$
#
# Запишем нормальное уравнение в матричном обозначении
#
# $$
# (J^TJ)Δw^k = J^T Δy^k
# $$
#
# В том случае, когда критерий оптимальности регрессионой модели задан как взвешенная сумма квадратов остатков
#
# $S = \sum\limits_{i = 1}^{n}W_{ii}r_i^2 \rightarrow min$
#
# нормальное уравнение будет иметь вид
#
# $$
# (J^TWJ)Δw^k = J^T W Δy^k
# $$
#
# В случае, если модель линейная, достаточно одной итерации по k.

# %% [markdown]
# ##Решение нелинейных уравнений

# %% [markdown]
# Рассмотрим решение нелинейных уравнений.
#
# Дана функция $f(x)$, заданная на отрезке $[a, b]$. Необходимо найти $x$, при котором функция обращается в 0.
#
# Простейшим методом нахождения корней уравнения $f(x) = 0$ является метод деления пополам.
#
# Предположим, мы нашли две точки $x_0$ и $x_1$, такие что функция в этих точках имеет разные знаки, тогда между этими точками находится хотя бы один корень функции.
#
# Разделим отрезок пополам $x_2 = \frac{x_1 + x_0}{2}$, тогда есть 3 варианта :
# * $f(x_2) = 0$
# * $f(x_1)f(x_2)<0$
# * $f(x_0)f(x_2)<0$
#
# Оставим нужную половину отрезка и проделаем так еще раз.

# %% [markdown]
# Следующий метод - метод Ньютона.
#
# Классический метод Ньютона или касательных заключается в том, что если $x_k$ — некоторое приближение к корню  уравнения, то следующее приближение определяется как корень касательной к функции, проведенной в этой точке.
#
# Уравнение касательной к функции в точке имеет вид:
#
# $f'(x_k) = \frac{y - f(x_k)}{x - x_k}$
#
# Найдем точку пересечения касательной с осью.
#
# $x_{k + 1} = x_{k} - \frac{f(x_k)}{f'(x_k)}$
#
# Сходимость метода касательных квадратичная, порядок сходимости равен 2.
#
# Таким образом, сходимость метода касательных Ньютона очень быстрая.

# %% [markdown]
# Для избежания вычисления производной можно использовоть метод секущих.
#
# В этом случае мы заменяем производную на приближенное значение, построенно по предыдущим точкам:
#
# $f^*(x_k) = \frac{f(x_k) - f(x_{k-1})}{x_k - x_{k-1}}$
#
# И сам итерационный процесс имеет вид:
#
# $x_{k + 1} =  x_k - \frac{f(x_k)}{f^*(x_k)}$

# %% [markdown]
# Нахождение всех корней уравнения.
#
# К сожалению, большая часть методов не позволяет найти все корни уравнения. Для нахождения всех корней можно воспользоваться методом удаления корней.
#
# После нахождения корня функция $f(x)$ заменяется на $f_1(x) = \frac{f(x)}{x - x_0}$, после чего ищем корни новой функции.
#
# Следует обратить внимание, что когда производим деление на тот или иной корень, то в действительности мы делим лишь на найденное приближение, и, тем самым, несколько сдвигаем корни вспомогательной функции относительно истинных корней функции. Это может привести к значительным погрешностям, если процедура отделения применялась уже достаточное число раз. Чтобы избежать этого, с помощью вспомогательных функций вычисляются лишь первые итерации, а окончательные проводятся по исходной функции, используя в качестве стартового приближения, последнюю итерацию, полученную по вспомогательной функции.

# %% [markdown]
# Реализуем метод Ньютона на практике, чтобы построить области притяжения разных корней нелинейного уравнения на комплексной плоскости. Разными цветами закрашены области притяжения для разных корней. Более тёмные области соответствуют большему числу итераций.

# %%
from scipy import optimize

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap


# A list of colors to distinguish the roots.
colors = ['b', 'r', 'g', 'y']

TOL = 1.e-8

def newton(z0, f, fprime, MAX_IT=1000):
    """The Newton-Raphson method applied to f(z).

    Returns the root found, starting with an initial guess, z0, or False
    if no convergence to tolerance TOL was reached within MAX_IT iterations.

    """

    z = z0
    try:
      z = optimize.newton(f, z0, fprime)
      return z
    except:
      return False

def plot_newton_fractal(f, fprime, n=200, domain=(-1, 1, -1, 1)):
    """Plot a Newton Fractal by finding the roots of f(z).

    The domain used for the fractal image is the region of the complex plane
    (xmin, xmax, ymin, ymax) where z = x + iy, discretized into n values along
    each axis.

    """

    roots = []
    m = np.zeros((n, n))

    def get_root_index(roots, r):
        """Get the index of r in the list roots.

        If r is not in roots, append it to the list.

        """

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# A list of colors to distinguish the roots.
colors = ['b', 'r', 'g', 'y']

TOL = 1.e-8

def newton(z0, f, fprime, MAX_IT=1000):
    """The Newton-Raphson method applied to f(z).

    Returns the root found, starting with an initial guess, z0, or False
    if no convergence to tolerance TOL was reached within MAX_IT iterations.

    """

    z = z0
    for i in range(MAX_IT):
        dz = f(z)/fprime(z)
        if abs(dz) < TOL:
            return z
        z -= dz
    return False

def plot_newton_fractal(f, fprime, n=200, domain=(-1, 1, -1, 1)):
    """Plot a Newton Fractal by finding the roots of f(z).

    The domain used for the fractal image is the region of the complex plane
    (xmin, xmax, ymin, ymax) where z = x + iy, discretized into n values along
    each axis.

    """

    roots = []
    m = np.zeros((n, n))

    def get_root_index(roots, r):
        """Get the index of r in the list roots.

        If r is not in roots, append it to the list.

        """

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# #Нелинейные задачи. Практика.

# %% [markdown]
# ##Задача 1. Метод Ньютона и Гаусса-Ньютона.

# %% [markdown]
# Решение проблемы многомерной линейной регрессии, изложенное выше, очень похоже на обобщение метода Ньютона на многомерный случай. Но это не так.
# Укажите, в чём различие между методами. В одномерном случае
#
# $$
# f(x) \approx f(x_0) + f^{\prime}(x_0)(x - x_0) = 0
# $$
#
# $$
# x =  x_0 - \frac{f(x_0)}{f^{\prime}(x_0)}
# $$
#
# Обобщение метода Ньютона на многомерный случай выглядит так.
#
# $$
# F(\vec{β}) \approx F(\vec{β^{(0)}}) + \sum\limits_{i=1}^n{\frac{∂F(\vec{β^{(0)}})}{∂β_i}(β_i - β^0_i)} = 0
# $$
#
# $$
# F(\vec{β^{(0)}}) + \nabla F(\vec{β^{(0)}})\vec{p}   = 0
# $$

# %% [markdown]
# В случае поиска минимума функции F к нулю приравниваем частные производные F
# $$
# \frac{∂F(\vec{β})}{∂β_i} \approx \frac{∂F(\vec{β^{(0)}})}{∂β_i} + \sum\limits_{j=1}^n{\frac{∂^2F(\vec{β^{(0)}})}{∂β_i∂β_j}(β_i - β^0_i)} = 0
# $$

# %% [markdown]
# Указание: покажите, что
#
# $$
# 2J^TJ  \neq   H_{ij}
# $$
#
# $H_{ij}$ - гессиан F.

# %% [markdown]
# ## Задача 2. Параболическая регрессия и гиперболическая.

# %% [markdown]
# Постройте нормальные уравнения метода наименьших квадратов (МНК) для параболы. Напишите функцию, которая вычисляет коэффициенты параболической регрессии для произвольных данных ($x_i, y_i$).
#
# Постройте нормальные уравнения метода наименьших квадратов (МНК) для гиперболы. Напишите функцию, которая вычисляет коэффициенты гиперболической регрессии для произвольных данных ($x_i, y_i$).
#
# В обоих случаях всё сводится к однократному решению СЛАУ, линеаризация и построение итераций не требуются.

# %% [markdown]
# ## Задача 3. Показательная и степенная регрессия.

# %% [markdown]
# Постройте нормальные уравнения метода наименьших квадратов (МНК) для
#
# $y = a_0*a^x$
#
# Напишите функцию, которая вычисляет коэффициенты регрессии для произвольных данных ($x_i, y_i$).
#
# Указание: свести к случаю линейной регрессии, взяв логарифм.
#
# $ln(y) = ln(a_0) + xln(a)$
#
# Показательная функция является внутренне линейной, поэтому оценки неизвестных параметров её линеаризованной формы можно рассчитать с помощью классического метода наименьших квадратов.
#
# Аналогичным образом постройте нормальные уравнения метода наименьших квадратов (МНК) для степенной функции. Напишите функцию, которая вычисляет коэффициенты регрессии для произвольных данных ($x_i, y_i$).

# %% [markdown]
# ## Задача 4. Показательная регрессия.

# %% [markdown]
# Постройте нормальные уравнения метода наименьших квадратов (МНК) для
#
# $y = a_0*a^x$
#
# Напишите функцию, которая вычисляет коэффициенты регрессии для произвольных данных ($x_i, y_i$).
#
# Указание: свести к случаю линейной регрессии, взяв логарифм.
#
# $ln(y) = ln(a_0) + xln(a)$
#
# Показательная функция является внутренне линейной, поэтому оценки неизвестных параметров её линеаризованной формы можно рассчитать с помощью классического метода наименьших квадратов

# %% [markdown]
# ## Задача 5. Сходимость метода Ньютона.

# %% [markdown]
# Покажите, что для функции $f(x) = |x|^{5/2}$ метод Ньютона сходится лишь линейно.

# %% [markdown]
# ##Задача 6. Функция Растригина.

# %% [markdown]
# Постройте множество локальных минимумов и максимум так, как на картинке.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
