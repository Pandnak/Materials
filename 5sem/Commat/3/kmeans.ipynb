# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def scatter_plot(data, col=None):
    from mpl_toolkits.mplot3d import Axes3D 
    # %matplotlib inline
    fig = plt.figure(figsize = (12, 9))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(data[:,0], data[:,1], data[:,2], s = 0.5, color=col)
    plt.show()

# %%
N = 10000   # число точек
K = 3       # число кластеров
d = 3       # размерность пространства
L = 10      #

# %%
# Generate some data
np.random.seed(45)
mu_true = np.random.uniform(-L, L, size = (K, d))
data = np.random.normal(mu_true, size = (N, K, d))
data = np.vstack(data)
np.random.shuffle(data)

# %%
if d == 3:
    scatter_plot(data, None)

# %%
# Рандомно выбранные центры 3х кластеров
mu = data[np.random.choice(data.shape[0], K, replace=False)]

# Создание массива с цветом каждой точки, 
# т.е.рандомное присвоение точки некоторому кластеру
c = np.random.randint(low=0, high=K-1, size=data.shape[0])

# %%
def dist_i(x, mu):
    # x: N datapoints, mu: N cluster centers
    # returns: D_{i}, squared distances from x[i] to mu[i]
    dist = np.zeros(x.shape[0])
#     for i in range(x.shape[0]):
#         dist[i] = np.sum((x[i] - mu[i])**2)
    dist = np.dot((x - mu).T, (x - mu))
    print(dist.shape)
    return dist
def dist_ij(x, mu):
    # x: N datapoints, mu: K cluster centers
    # returns: D_{ij}, squared distances from x[i] to mu[j]
    dist = np.zeros((x.shape[0], mu.shape[0]))
    for i in range(x.shape[0]):
        for j in range(mu.shape[0]):
            dist[i, j] += np.sum((x[i] - mu[j])**2)
    return dist

# %%
print(mu.shape)
# Out:
# (3, 3)

# %%
ss_list = []
for n in range(10):
    c =  np.argmin(dist_ij(data, mu), axis = 1)    
    ss = np.mean(dist_i(data, mu[c]))
    ss_list.append(ss)    
    for i in range(K):
        cluster_members = data[c == i]
        cluster_members = cluster_members.mean(axis = 0)
        mu[i] = cluster_members
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       2 for n in range(10):
#       3     c =  np.argmin(dist_ij(data, mu), axis = 1)
# ----> 4     ss = np.mean(dist_i(data, mu[c]))
#       5     ss_list.append(ss)
#       6     for i in range(K):
#
# Input In [33], in dist_i(x, mu)
#       4     dist = np.zeros(x.shape[0])
#       5 #     for i in range(x.shape[0]):
#       6 #         dist[i] = np.sum((x[i] - mu[i])**2)
# ----> 7     dist = np.tensordot((x - mu).T, (x - mu), axes = 2)
#       8     print(dist.shape)
#       9     return dist
#
# File <__array_function__ internals>:5, in tensordot(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py:1110, in tensordot(a, b, axes)
#    1108             axes_b[k] += ndb
#    1109 if not equal:
# -> 1110     raise ValueError("shape-mismatch for sum")
#    1112 # Move the axes to sum over to the end of "a"
#    1113 # and to the front of "b"
#    1114 notin = [k for k in range(nda) if k not in axes_a]
#
# ValueError: shape-mismatch for sum

# %%
plt.plot(ss_list)

# %%
colors = np.array([plt.cm.cool(i/(K-1)) for i in range(K)])

# %%
if d == 3:
    scatter_plot(data, colors[c])
